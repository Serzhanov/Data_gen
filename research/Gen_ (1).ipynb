# %%
#https://github.com/Trainingdata-datamarket/TrainingData_All_datasets?tab=readme-ov-file
import matplotlib.pyplot as plt

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# Read the images
img = cv.imread('carte_vitale.jpg')
mask = cv.imread('masked_image.png', cv.IMREAD_GRAYSCALE)

# Perform inpainting
dst = cv.inpaint(img, mask, 3, cv.INPAINT_TELEA)

# Convert BGR to RGB
dst_rgb = cv.cvtColor(dst, cv.COLOR_BGR2RGB)

# Display the image
plt.imshow(dst_rgb)
plt.axis('off')  # Optional: Turn off axis numbers
plt.show()

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

#RESULT FROM LABELSTUDIO

# Your provided JSON object
data_str = '''[{"id":1,"annotations":[{"id":1,"completed_by":1,"result":[{"original_width":3790,"original_height":2407,"image_rotation":0,"value":{"x":70.32590051457976,"y":7.562277263071331,"width":20.411663807890235,"height":43.888216258896115,"rotation":0,"rectanglelabels":["Label2"]},"id":"hmEBuVzAj2","from_name":"bbox","to_name":"image","type":"rectanglelabels","origin":"manual"},{"original_width":3790,"original_height":2407,"image_rotation":0,"value":{"x":70.32590051457976,"y":7.562277263071331,"width":20.411663807890235,"height":43.888216258896115,"rotation":0,"text":["image"]},"id":"hmEBuVzAj2","from_name":"transcription","to_name":"image","type":"textarea","origin":"manual"},{"original_width":3790,"original_height":2407,"image_rotation":0,"value":{"x":29.93138936535163,"y":44.96854158219202,"width":29.24528301886792,"height":5.671707947303503,"rotation":0,"rectanglelabels":["Label3"]},"id":"7tmJ4UT5Om","from_name":"bbox","to_name":"image","type":"rectanglelabels","origin":"manual"},{"original_width":3790,"original_height":2407,"image_rotation":0,"value":{"x":29.93138936535163,"y":44.96854158219202,"width":29.24528301886792,"height":5.671707947303503,"rotation":0,"text":["émise le 15\/09\/2020"]},"id":"7tmJ4UT5Om","from_name":"transcription","to_name":"image","type":"textarea","origin":"manual"},{"original_width":3790,"original_height":2407,"image_rotation":0,"value":{"x":28.130360205831906,"y":68.33057669846595,"width":10.463121783876502,"height":4.5913826240075934,"rotation":0,"rectanglelabels":["Label3"]},"id":"Uy10WVVsog","from_name":"bbox","to_name":"image","type":"rectanglelabels","origin":"manual"},{"original_width":3790,"original_height":2407,"image_rotation":0,"value":{"x":28.130360205831906,"y":68.33057669846595,"width":10.463121783876502,"height":4.5913826240075934,"rotation":0,"text":["Nurbek"]},"id":"Uy10WVVsog","from_name":"transcription","to_name":"image","type":"textarea","origin":"manual"},{"original_width":3790,"original_height":2407,"image_rotation":0,"value":{"x":28.387650085763294,"y":73.46212198412145,"width":20.583190394511146,"height":4.726423289419576,"rotation":0,"rectanglelabels":["Label3"]},"id":"dVi0d2kmxF","from_name":"bbox","to_name":"image","type":"rectanglelabels","origin":"manual"},{"original_width":3790,"original_height":2407,"image_rotation":0,"value":{"x":28.387650085763294,"y":73.46212198412145,"width":20.583190394511146,"height":4.726423289419576,"rotation":0,"text":["SERZHANOV"]},"id":"dVi0d2kmxF","from_name":"transcription","to_name":"image","type":"textarea","origin":"manual"},{"original_width":3790,"original_height":2407,"image_rotation":0,"value":{"x":28.47341337907374,"y":84.13033455166855,"width":33.01886792452831,"height":4.591382624007675,"rotation":0,"rectanglelabels":["Label3"]},"id":"8c8nYHkbJm","from_name":"bbox","to_name":"image","type":"rectanglelabels","origin":"manual"},{"original_width":3790,"original_height":2407,"image_rotation":0,"value":{"x":28.47341337907374,"y":84.13033455166855,"width":33.01886792452831,"height":4.591382624007675,"rotation":0,"text":["1 11 11 11 111 111 11"]},"id":"8c8nYHkbJm","from_name":"transcription","to_name":"image","type":"textarea","origin":"manual"},{"original_width":3790,"original_height":2407,"image_rotation":0,"value":{"x":92.53859348198985,"y":6.887073936011369,"width":2.830188679245317,"height":54.82651015726713,"rotation":0,"rectanglelabels":["Label3"]},"id":"uTN-QKHcCQ","from_name":"bbox","to_name":"image","type":"rectanglelabels","origin":"manual"},{"original_width":3790,"original_height":2407,"image_rotation":0,"value":{"x":92.53859348198985,"y":6.887073936011369,"width":2.830188679245317,"height":54.82651015726713,"rotation":0,"text":["1111111111 111111111 1"]},"id":"uTN-QKHcCQ","from_name":"transcription","to_name":"image","type":"textarea","origin":"manual"}],"was_cancelled":false,"ground_truth":false,"created_at":"2024-02-15T16:33:53.526010Z","updated_at":"2024-02-15T16:33:53.526037Z","draft_created_at":"2024-02-15T16:26:01.460815Z","lead_time":292.99899999999997,"prediction":{},"result_count":0,"unique_id":"7225653a-df6b-43eb-b7cb-26eb12cd2db6","import_id":null,"last_action":null,"task":1,"project":1,"updated_by":1,"parent_prediction":null,"parent_annotation":null,"last_created_by":null}],"file_upload":"f84811dc-1708014002198.jpg","drafts":[],"predictions":[],"data":{"ocr":"\/data\/upload\/1\/f84811dc-1708014002198.jpg"},"meta":{},"created_at":"2024-02-15T16:21:30.621347Z","updated_at":"2024-02-15T16:33:53.593409Z","inner_id":1,"total_annotations":1,"cancelled_annotations":0,"total_predictions":0,"comment_count":0,"unresolved_comment_count":0,"last_comment_updated_at":null,"project":1,"updated_by":1,"comment_authors":[]}]'''

# Parsing the JSON data
data = json.loads(data_str)

# Image dimensions
image_width = 3790
image_height = 2407

# %%
data
# Out:
# [{'id': 1,
#   'annotations': [{'id': 1,
#     'completed_by': 1,
#     'result': [{'original_width': 3790,
#       'original_height': 2407,
#       'image_rotation': 0,
#       'value': {'x': 70.32590051457976,
#        'y': 7.562277263071331,
#        'width': 20.411663807890235,
#        'height': 43.888216258896115,
#        'rotation': 0,
#        'rectanglelabels': ['Label2']},
#       'id': 'hmEBuVzAj2',
#       'from_name': 'bbox',
#       'to_name': 'image',
#       'type': 'rectanglelabels',
#       'origin': 'manual'},
#      {'original_width': 3790,
#       'original_height': 2407,
#       'image_rotation': 0,
#       'value': {'x': 70.32590051457976,
#        'y': 7.562277263071331,
#        'width': 20.411663807890235,
#        'height': 43.888216258896115,
#        'rotation': 0,
#        'text': ['image']},
#       'id': 'hmEBuVzAj2',
#       'from_name': 'transcription',
#       'to_name': 'image',
#       'type': 'textarea',
#       'origin': 'manual'},
# ...

# %%
dst_rgb_pil = Image.fromarray(dst_rgb)
draw = ImageDraw.Draw(dst_rgb_pil)
font_path = "Arial.ttf"  # Update this to the location of the Arial.ttf on your system
font_size = 110  # Adjust size as needed for your image
font = ImageFont.truetype(font_path, font_size)

for annotation_data in data:
    for annotation in annotation_data['annotations']:
        for result in annotation['result']:
            # Exclude 'image' text
            if 'text' in result['value'] and result['value']['text'][0].lower() != 'image':
                text = result['value']['text'][0]  # Get the text

                # Calculate the position to draw the text
                x = int(result['value']['x'] / 100 * result['original_width'])
                y = int(result['value']['y'] / 100 * result['original_height'])

                # Create a transparent image for text
                text_size = font.getsize(text)
                text_image = Image.new('RGBA', text_size, (255, 255, 255, 0))
                draw_text = ImageDraw.Draw(text_image)

                # Draw text onto the transparent image
                draw_text.text((0, 0), text, font=font, fill=(0, 0, 0))

                # Rotate the text image by 90 degrees if needed
                if text == '1111111111 111111111 1':
                    text_image = text_image.rotate(90, expand=1)

                # Paste the rotated text image onto the original image
                dst_rgb_pil.paste(text_image, (x, y), text_image)


# Display the image with the text
plt.imshow(dst_rgb_pil)
plt.axis('off')  # Hide the axes
plt.show()
# Out:
# <ipython-input-10-39fd1052ada3>:19: DeprecationWarning: getsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use getbbox or getlength instead.
#   text_size = font.getsize(text)

# %%
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-22-a64107496846> in <cell line: 26>()
#      24
#      25 # Ensure 'texts' list has enough entries to match annotations
# ---> 26 assert len(texts) >= len(data[0]['annotations'][0]['result']), "Not enough texts for annotations"
#      27
#      28 for annotation in data[0]['annotations'][0]['result']:
#
# AssertionError: Not enough texts for annotations

# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# Load your image into Pillow
#dst_rgb = Image.open('path_to_your_image.jpg')

# Specify your Arial font file path
font_path = "Arial.ttf"  # Update this to the location of the arial.ttf on your system
dst_rgb_pil = Image.fromarray(cv.cvtColor(dst_rgb, cv.COLOR_BGR2RGB))

# Font settings
font_size = 150  # Adjust the size to match the scale in your original image
font = ImageFont.truetype(font_path, font_size)
color = (0, 0, 0)  # Font color in RGB (black)

# A dummy 'data' variable for demonstration; replace with your actual data structure
data = [{'annotations': [{'result': [{'value': {'x': 10, 'y': 10, 'width': 100, 'height': 100, 'rectanglelabels': ['Label1']}}]}]}]


# Iterate over each annotation and add text
i = 0
texts = ['', 'émise le xx/xx/xxxx', 'Nurbek', 'SERZHANOV', 'x xx xx xx xxx xxx xx', 'info']
draw = ImageDraw.Draw(dst_rgb_pil)

for annotation in data[0]['annotations'][0]['result']:
    if 'rectanglelabels' in annotation['value']:
        # Extracting the coordinates
        x = int(annotation['value']['x'] / 100 * image_width)
        y = int(annotation['value']['y'] / 100 * image_height)
        text = texts[i]  # Replace or modify as needed
        i += 1
        # Add text to the image
        draw.text((x, y), text, font=font, fill=color)

# Convert back to numpy array if needed for further OpenCV processing
#dst_rgb_np = np.array(dst_rgb_pil)

# If you want to display using OpenCV, convert RGB back to BGR

# Display the image with the text
plt.imshow(dst_rgb_pil)
plt.axis('off')
plt.show()

# %%
font = cv.FONT_HERSHEY_SIMPLEX  # You can choose different fonts
font_scale = 4.1  # Font size
color = (0, 0, 0)  # Font color in BGR (white)
thickness = 20  # Font thickness
i=0
texts=['','émise le xx/xx/xxxx','Nurbek','SERZHANOV','x xx xx xx xxx xxx xx','info']
# Iterate over each annotation and add text
for annotation in data[0]['annotations'][0]['result']:
    if 'rectanglelabels' in annotation['value']:
        # Extracting the coordinates
        x = int(annotation['value']['x'] / 100 * image_width)
        y = int(annotation['value']['y'] / 100 * image_height)

        # Text to be added
        text = texts[i]  # Replace or modify as needed
        i+=1
        # Add text to the image
        cv.putText(dst_rgb, text, (x, y), font, font_scale, color, thickness, cv.LINE_AA)

# Display the image with the text
plt.imshow(dst_rgb)
plt.axis('off')
plt.show()

# %%
import cv2 as cv

# Your text and font settings
text = "Nurbek"
font = cv.FONT_HERSHEY_SIMPLEX  # You can choose different fonts
font_scale = 1  # Font size
color = (0, 0, 0)  # Font color in BGR (white)
thickness = 2  # Font thickness

# Location to put the text - for example, top left corner of the first mask
# You can adjust these coordinates based on your specific requirements
x, y = 100, 100  # Replace these with your coordinates

# Add text to the image
cv.putText(dst_rgb, text, (x, y), font, font_scale, color, thickness, cv.LINE_AA)

# Display the image with the text
plt.imshow(dst_rgb)
plt.axis('off')
plt.show()

# %%
import numpy as np
import cv2 as cv
img = cv.imread('carte_vitale.jpg')
mask = cv.imread('masked_image.png', cv.IMREAD_GRAYSCALE)
dst = cv.inpaint(img,mask,3,cv.INPAINT_TELEA)
plt.imshow(dst)
plt.show()
